# %%
import cv2
import mediapipe as mp 
import numpy as np 
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
cap = cv2.VideoCapture(0)
mpHands = mp.solutions.hands
Hands = mpHands.Hands()
draw = mp.solutions.drawing_utils
# Media File uses RGB Format

# %%
while True:
    success, img = cap.read()
    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = Hands.process(rgb)

    num_cors = 20
    landmarks = []
    for val in range(0, num_cors + 1):
        landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val)]
    landmarks +=['Digit']
    
    with open('cords.csv', mode = 'w', newline = '') as f:
        csv_writer = csv.writer(f, delimiter = ",", quotechar = '"', quoting = csv.QUOTE_MINIMAL)
        csv_writer.writerow(landmarks)

    if results.multi_hand_landmarks:
        for id, hands in enumerate(results.multi_hand_landmarks):
            draw.draw_landmarks(img,hands,mpHands.HAND_CONNECTIONS)
            if (hands.landmark[8].x > 0.6):
                cv2.putText(img, "You are in right part of the screen",(255//2,255//2), cv2.FONT_HERSHEY_TRIPLEX, 1.0,(0,255,0),thickness = 2)
            elif (hands.landmark[8].x < 0.4):
                cv2.putText(img, "You are in left part of the screen",(255//2,255//2), cv2.FONT_HERSHEY_TRIPLEX, 1.0,(0,0,255),thickness = 2)
            else :
                cv2.putText(img, "You are in middle part of the screen",(255//2,255//2), cv2.FONT_HERSHEY_TRIPLEX, 1.0,(255,0,0),thickness = 2)

            x_cor = []
            y_cor = []
            z_cor = []

            def coord(x_cor,y_cor, z_cor, hands):
                for i in range(0,21):
                    x_cor.append(hands.landmark[i].x)
                    y_cor.append(hands.landmark[i].y)
                    z_cor.append(hands.landmark[i].z)
                return x_cor, y_cor, z_cor 

            x_cor, y_cor, z_cor = coord(x_cor, y_cor, z_cor, hands)
            hands_row = list(np.array([x_cor, y_cor, z_cor]).flatten())
            # print(hands_row)

            with open('coords.csv', mode = 'a', newline = '') as f:
                csv_writer = csv.writer(f, delimiter = ',', quotechar = '"', quoting= csv.QUOTE_MINIMAL)
                csv_writer.writerow(hands_row)
    cv2.imshow("img", img)
    if cv2.waitKey(1) == ord('q'):
        break

# %%
df = pd.read_csv('coords.csv')
df.dropna(axis = 0, inplace = True)
df
y = df['Digit']
X = df.drop('Digit',axis = 1)
X
# Out:
#             x0        y0        z0        x1        y1        z1        x2  \
# 0     0.075102  0.138061  0.192487  0.196253  0.147870  0.140955  0.152719
# 1     0.064627  0.134461  0.186154  0.191971  0.144788  0.136537  0.152758
# 2     0.065773  0.135970  0.186284  0.193666  0.148091  0.138861  0.154853
# 3     0.064336  0.137701  0.192638  0.201887  0.153895  0.146072  0.162799
# 4     0.086643  0.157288  0.212225  0.220500  0.172849  0.165430  0.179837
# ...        ...       ...       ...       ...       ...       ...       ...
# 1106  0.518828  0.450264  0.440281  0.461518  0.486520  0.526177  0.479302
# 1107  0.533129  0.471381  0.459504  0.469269  0.491529  0.552105  0.508423
# 1108  0.563913  0.506050  0.495416  0.512350  0.535406  0.583769  0.536824
# 1109  0.579023  0.566608  0.553277  0.545698  0.555993  0.628723  0.578782
# 1110  0.579866  0.638941  0.650881  0.635235  0.614738  0.686261  0.631803
#
#             y2        z2        x3  ...       z17       x18       y18  \
# 0     0.154465  0.152090  0.086780  ... -0.085902 -0.094177 -0.024193
# 1     0.157240  0.157505  0.083856  ... -0.077748 -0.085539 -0.013563
# 2     0.157405  0.157578  0.089072  ... -0.080921 -0.089385 -0.016342
# 3     0.167157  0.169105  0.096618  ... -0.078934 -0.089521 -0.010215
# 4     0.185276  0.186611  0.118844  ... -0.067424 -0.074846 -0.010648
# ...        ...       ...       ...  ...       ...       ...       ...
# 1106  0.466171  0.471284  0.575012  ...  0.016133  0.010140  0.007383
# 1107  0.499441  0.506157  0.597614  ...  0.004047 -0.000762  0.004936
# 1108  0.527451  0.534292  0.624961  ... -0.008171 -0.014951  0.000407
# 1109  0.563794  0.566192  0.640739  ... -0.006073 -0.014519 -0.000736
# 1110  0.614848  0.614722  0.657300  ...  0.004413  0.000080  0.007890
#
#            z18       x19       y19       z19       x20       y20       z20
# 0    -0.063507 -0.073593 -0.070444 -0.031090 -0.062236 -0.069027 -0.067312
# 1    -0.053970 -0.065996 -0.062093 -0.023901 -0.051854 -0.058883 -0.057206
# 2    -0.053036 -0.064094 -0.061484 -0.026575 -0.049633 -0.055337 -0.054145
# 3    -0.049797 -0.065300 -0.065156 -0.020602 -0.047786 -0.058056 -0.059820
# 4    -0.043562 -0.053167 -0.050473 -0.020484 -0.041474 -0.046168 -0.044760
# ...        ...       ...       ...       ...       ...       ...       ...
# 1106  0.019542  0.018732  0.014360  0.008484  0.018590  0.027916  0.034822
# 1107  0.009723  0.010317  0.008876  0.007895  0.012353  0.020893  0.028188
# 1108  0.001749  0.001919  0.000598 -0.000590  0.001817  0.010217  0.017641
# 1109  0.003805  0.005130  0.002617 -0.005816  0.000136  0.009426  0.016043
# 1110  0.006290  0.006989  0.006663  0.003757  0.001347  0.007108  0.013417
#
# [1111 rows x 63 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=10, random_state=0)
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.9809264305177112
